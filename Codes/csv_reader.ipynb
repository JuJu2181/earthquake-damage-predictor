# %% [markdown]
# This notebook is simply for reading all the results csv files

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import os

# %%
sample_data = pd.read_csv('../Results/sampling_methods.csv')
sample_data.head()
# Out:
#    Unnamed: 0               Model Name  Accuracy_Test  Accuracy_Train  \
# 0           0                   Normal       0.713532        0.714039
# 1           1      Random Oversampling       0.713495        0.662418
# 2           2       SMOTE Oversampling       0.716540        0.661617
# 3           3     Random Undersampling       0.713894        0.662895
# 4           4  Near Miss Undersampling       0.693913        0.741043
#
#    Precision_Test  Precision_Train  Recall_Test  Recall_Train  F1_Score_Test  \
# 0        0.717065         0.718432     0.713532      0.714039       0.698504
# 1        0.719238         0.666584     0.713495      0.662418       0.708035
# 2        0.722646         0.663711     0.716540      0.661617       0.714315
# 3        0.720699         0.668616     0.713894      0.662895       0.708431
# 4        0.698761         0.714536     0.693913      0.741043       0.670236
#
#    F1_Score_Train
# 0        0.699440
# 1        0.655470
# 2        0.658882
# ...

# %%
df = pd.read_csv('../Results/sampling_methods_no_params.csv')
df.head()
# Out:
#    Unnamed: 0               Model Name  Accuracy_Test  Accuracy_Train  \
# 0           0                   Normal       0.773745        0.996336
# 1           1      Random Oversampling       0.769378        0.996662
# 2           2       SMOTE Oversampling       0.773299        0.997572
# 3           3     Random Undersampling       0.761726        0.997138
# 4           4  Near Miss Undersampling       0.701770        0.999008
#
#    Precision_Test  Precision_Train  Recall_Test  Recall_Train  F1_Score_Test  \
# 0        0.775141         0.996337     0.773745      0.996336       0.773801
# 1        0.772624         0.996664     0.769378      0.996662       0.770718
# 2        0.776593         0.997572     0.773299      0.997572       0.774555
# 3        0.771019         0.997138     0.761726      0.997138       0.764857
# 4        0.700114         0.999008     0.701770      0.999008       0.698437
#
#    F1_Score_Train
# 0        0.996336
# 1        0.996662
# 2        0.997572
# ...

# %%
df = pd.read_csv('../Results/sampling_methods_tune1.csv')
df.head()
# Out:
#    Unnamed: 0            Model Name  Accuracy_Test  Accuracy_Train  \
# 0           0                Normal       0.774685        0.822207
# 1           1   Random Oversampling       0.774391        0.860454
# 2           2  Random Undersampling       0.764665        0.801245
#
#    Precision_Test  Precision_Train  Recall_Test  Recall_Train  F1_Score_Test  \
# 0        0.777916         0.827563     0.774685      0.822207       0.772696
# 1        0.781040         0.863030     0.774391      0.860454       0.776470
# 2        0.773913         0.806666     0.764665      0.801245       0.767060
#
#    F1_Score_Train
# 0        0.821312
# 1        0.860974
# 2        0.802177

# %%
df = pd.read_csv('../Results/sampling_methods_net_floor_height.csv')
df.head()
# Out:
#    Unnamed: 0            Model Name  Accuracy_Test  Accuracy_Train  \
# 0           0                Normal       0.731146        0.749855
# 1           1   Random Oversampling       0.722761        0.735611
# 2           2  Random Undersampling       0.721365        0.703191
#
#    Precision_Test  Precision_Train  Recall_Test  Recall_Train  F1_Score_Test  \
# 0        0.737879         0.757903     0.731146      0.749855       0.729433
# 1        0.733074         0.746924     0.722761      0.735611       0.722239
# 2        0.733419         0.715804     0.721365      0.703191       0.720206
#
#    F1_Score_Train
# 0        0.748666
# 1        0.734456
# 2        0.700921

# %%
df = pd.read_csv('../Results/sampling_methods_net_floor_height_pca.csv')
df.head()
# Out:
#    Unnamed: 0            Model Name  Accuracy_Test  Accuracy_Train  \
# 0           0                Normal       0.725742        0.842372
# 1           1   Random Oversampling       0.716029        0.889136
# 2           2  Random Undersampling       0.712458        0.830180
#
#    Precision_Test  Precision_Train  Recall_Test  Recall_Train  F1_Score_Test  \
# 0        0.728641         0.850014     0.725742      0.842372       0.721893
# 1        0.722765         0.891399     0.716029      0.889136       0.716801
# 2        0.723755         0.835038     0.712458      0.830180       0.714128
#
#    F1_Score_Train
# 0        0.842096
# 1        0.889784
# 2        0.831488
